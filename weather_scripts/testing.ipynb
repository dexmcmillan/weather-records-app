# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# # Run this section if you need to recover corrupted data

# %%
raw = pd.read_csv("./data/data-historical-both.csv", index_col="Climate ID", low_memory=False)

# %%
raw = raw.drop(columns=["Unnamed: 0"])

raw.tail(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\dexmc\Documents\Code\weather-records-app\weather_scripts\testing.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> raw = raw.drop(columns=["Unnamed: 0"])
#       <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> raw.tail(3)
#
# File c:\Users\dexmc\anaconda3\envs\geo\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\dexmc\anaconda3\envs\geo\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
#    4812     Drop specified labels from rows or columns.
#    4813
#    (...)
#    4946             weight  1.0     0.8
#    4947     """
# -> 4948     return super().drop(
#    4949         labels=labels,
#    4950         axis=axis,
#    4951         index=index,
#    4952         columns=columns,
#    4953         level=level,
#    4954         inplace=inplace,
#    4955         errors=errors,
#    4956     )
#
# File c:\Users\dexmc\anaconda3\envs\geo\lib\site-packages\pandas\core\generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File c:\Users\dexmc\anaconda3\envs\geo\lib\site-packages\pandas\core\generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File c:\Users\dexmc\anaconda3\envs\geo\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
stations = pd.read_csv("./data/stations_cma.csv", index_col="Climate ID")

stations.head(3)
# Out:
#             Station ID                   Name     Latitude     Longitude  \
# Climate ID
# 1010774             18            BEAVER LAKE  483000000.0 -1.232100e+09
# 1010960             20        BRENTWOOD BAY 2  483600000.0 -1.232800e+09
# 1010961             21  BRENTWOOD CLARKE ROAD  483400000.0 -1.232700e+09
#
#             First Year  Last Year  DLY First Year  DLY Last Year  CMAUID  \
# Climate ID
# 1010774           1894       1952          1894.0         1952.0     935
# 1010960           1987       1997          1987.0         1997.0     935
# 1010961           1972       1980          1972.0         1980.0     935
#
#              CMANAME PRUID
# Climate ID
# 1010774     Victoria    BC
# 1010960     Victoria    BC
# 1010961     Victoria    BC

# %%
stations[stations["DLY Last Year"].isna()]
# Out:
#             Station ID                      Name     Latitude     Longitude  \
# Climate ID
# 1021267          51317          CAMPBELL RIVER A  495707000.0 -1.251623e+09
# 1046395          51438            POWELL RIVER A  495003000.0 -1.243001e+09
# 1068133          10750  TERRACE SKEENA BRIDGE CS  543100000.0 -1.283400e+09
# 1093598            594                  HORSEFLY  522000000.0 -1.212500e+09
# 3013958          50311            LLOYDMINSTER A  531838000.0 -1.100427e+09
# ...                ...                       ...          ...           ...
# 8200576          26824               BEDFORD MWO  444400000.0 -6.340000e+08
# 8202221          49128           HALIFAX COMMONS  443800000.0 -6.335000e+08
# 8205697          10970                SYDNEY CCR  461003000.0 -6.009530e+08
# 8401710          10968                GANDER CCR  485642000.0 -5.435020e+08
# 8402478           7089                KELLIGREWS  473000000.0 -5.301000e+08
#
#             First Year  Last Year  DLY First Year  DLY Last Year  CMAUID  \
# Climate ID
# 1021267           2013       2022             NaN            NaN     944
# 1046395           2013       2022             NaN            NaN     945
# 1068133           1999       2002             NaN            NaN     965
# 1093598           1961       1962             NaN            NaN     950
# 3013958           2012       2022             NaN            NaN     840
# ...                ...        ...             ...            ...     ...
# 8200576           1995       1998             NaN            NaN     205
# 8202221           2010       2011             NaN            NaN     205
# 8205697           1994       1995             NaN            NaN     225
# 8401710           1994       1995             NaN            NaN      11
# 8402478           1987       1989             NaN            NaN       1
#
#                                                       CMANAME PRUID
# Climate ID
# 1021267                                        Campbell River    BC
# 1046395                                          Powell River    BC
# 1068133                                               Terrace    BC
# 1093598                                         Williams Lake    BC
# 3013958     Lloydminster (Alberta part / partie de l'Alberta)    AB
# ...                                                       ...   ...
# 8200576                                               Halifax    NS
# 8202221                                               Halifax    NS
# 8205697                                           Cape Breton    NS
# 8401710                                                Gander    NL
# 8402478                                            St. John's    NL
#
# [82 rows x 11 columns]

# %%
joined = raw.join(stations).dropna()

joined["Day"] = pd.to_datetime(joined["Date/Time"]).dt.day
joined["Month"] = pd.to_datetime(joined["Date/Time"]).dt.month
joined["Year"] = pd.to_datetime(joined["Date/Time"]).dt.year

# %%
minimums = (joined
            .pivot_table(columns="Year", values="Min Temp (°C)", index=["CMANAME", "Month", "Day"], aggfunc='min')
            .reset_index()
            .melt(id_vars=["CMANAME", "Month", "Day"])
            .dropna()
            )

minimums.tail()
# Out:
#          CMANAME  Month  Day  Year  value
# 9772704  Yorkton     11   17  2022  -20.4
# 9772705  Yorkton     11   18  2022  -16.4
# 9772706  Yorkton     11   19  2022  -17.9
# 9772707  Yorkton     11   20  2022  -16.0
# 9772708  Yorkton     11   21  2022  -12.4

# %%
minimums[minimums["CMANAME"] == "Weyburn"]
# Out:
#          CMANAME  Month  Day  Year  value
# 4108615  Weyburn      9    1  1916   12.8
# 4108616  Weyburn      9    2  1916   10.0
# 4108617  Weyburn      9    3  1916   15.6
# 4108618  Weyburn      9    4  1916   12.2
# 4108619  Weyburn      9    5  1916   10.0
# ...          ...    ...  ...   ...    ...
# 9769410  Weyburn     11   17  2022  -19.1
# 9769411  Weyburn     11   18  2022  -18.7
# 9769412  Weyburn     11   19  2022  -14.6
# 9769413  Weyburn     11   20  2022  -12.3
# 9769414  Weyburn     11   21  2022  -14.1
#
# [27736 rows x 5 columns]

# %%
minimums.to_csv("./data/raw_data-min.csv")

# %%
maximums = (joined
            .pivot_table(columns="Year", values="Max Temp (°C)", index=["CMANAME", "Month", "Day"], aggfunc='max')
            .reset_index()
            .melt(id_vars=["CMANAME", "Month", "Day"])
            .dropna()
            )

maximums
# Out:
#          CMANAME  Month  Day  Year  value
# 46143    Toronto      3    1  1840    8.3
# 46144    Toronto      3    2  1840    7.8
# 46145    Toronto      3    3  1840   11.1
# 46146    Toronto      3    4  1840   15.0
# 46147    Toronto      3    5  1840    6.7
# ...          ...    ...  ...   ...    ...
# 9772704  Yorkton     11   17  2022   -9.7
# 9772705  Yorkton     11   18  2022   -6.0
# 9772706  Yorkton     11   19  2022   -6.4
# 9772707  Yorkton     11   20  2022   -2.9
# 9772708  Yorkton     11   21  2022   -1.6
#
# [5372255 rows x 5 columns]

# %%
maximums[maximums["CMANAME"] == "Weyburn"]
# Out:
#          CMANAME  Month  Day  Year  value
# 4108615  Weyburn      9    1  1916   20.0
# 4108616  Weyburn      9    2  1916   25.0
# 4108617  Weyburn      9    3  1916   23.9
# 4108618  Weyburn      9    4  1916   25.0
# 4108619  Weyburn      9    5  1916   20.0
# ...          ...    ...  ...   ...    ...
# 9769410  Weyburn     11   17  2022   -9.8
# 9769411  Weyburn     11   18  2022   -7.3
# 9769412  Weyburn     11   19  2022   -4.9
# 9769413  Weyburn     11   20  2022   -0.2
# 9769414  Weyburn     11   21  2022   -2.5
#
# [27736 rows x 5 columns]

# %%
maximums.to_csv("./data/raw_data-max.csv")

# %% [markdown]
# # Scrap

# %%
year_counts = []

for city in maximums.reset_index()["CMANAME"].unique():
    saint_john = maximums.reset_index()
    saint_john = saint_john[saint_john["CMANAME"] == city].dropna(axis=1, how='all').set_index(["CMANAME", "Month", "Day"]).columns
    saint_john = pd.DataFrame({"city": [city], "years": [len(saint_john)]})
    
    year_counts.append(saint_john)
    
df = pd.concat(year_counts)

df.sort_values("years")
# Out:
#                                             city  years
# 0                                     High River      3
# 0                                      Ingersoll     10
# 0                                        Camrose     14
# 0                                   Wasaga Beach     16
# 0   Campbellton (partie du Québec / Quebec part)     23
# ..                                           ...    ...
# 0                                      Woodstock    152
# 0                                         London    152
# 0                                   Peterborough    155
# 0                                       Hamilton    156
# 0                                        Toronto    183
#
# [146 rows x 2 columns]

# %%
cmasWithEnoughData = df.loc[df["years"] >= 5, "city"].to_list()
cmasWithEnoughData
# Out:
# ['Abbotsford - Mission',
#  'Alma',
#  'Amos',
#  'Baie-Comeau',
#  'Barrie',
#  'Bathurst',
#  'Belleville - Quinte West',
#  'Brandon',
#  'Brantford',
#  'Brockville',
#  'Brooks',
#  'Calgary',
#  'Campbell River',
#  'Campbellton (New Brunswick part / partie du Nouveau-Brunswick)',
#  'Campbellton (partie du Québec / Quebec part)',
#  'Camrose',
#  'Cape Breton',
#  'Centre Wellington',
#  'Charlottetown',
#  'Chatham-Kent',
#  'Chilliwack',
#  'Cobourg',
#  'Collingwood',
#  'Corner Brook',
#  'Cornwall',
#  'Courtenay',
#  'Cranbrook',
#  'Dawson Creek',
#  'Dolbeau-Mistassini',
#  'Drummondville',
#  'Duncan',
#  'Edmonton',
#  'Edmundston',
#  'Elliot Lake',
#  'Essa',
#  'Estevan',
#  'Fort St. John',
#  'Fredericton',
#  'Gander',
#  'Granby',
#  'Grande Prairie',
#  'Greater Sudbury / Grand Sudbury',
#  'Guelph',
#  'Halifax',
#  'Hamilton',
#  'Ingersoll',
#  'Joliette',
#  'Kamloops',
#  'Kawartha Lakes',
#  'Kelowna',
#  'Kenora',
#  'Kentville',
#  'Kingston',
#  'Kitchener - Cambridge - Waterloo',
#  'Lachute',
#  'Lacombe',
#  'Ladysmith',
#  'Lethbridge',
#  "Lloydminster (Alberta part / partie de l'Alberta)",
#  'Lloydminster (Saskatchewan part / partie de la Saskatchewan)',
#  'London',
#  'Matane',
#  'Medicine Hat',
#  'Miramichi',
#  'Moncton',
#  'Montréal',
#  'Moose Jaw',
#  'Nanaimo',
#  'Nelson',
#  'New Glasgow',
#  'Norfolk',
#  'North Battleford',
#  'North Bay',
#  'Okotoks',
#  'Orillia',
#  'Oshawa',
#  "Ottawa - Gatineau (Ontario part / partie de l'Ontario)",
#  'Ottawa - Gatineau (partie du Québec / Quebec part)',
#  'Owen Sound',
#  'Parksville',
#  'Pembroke',
#  'Penticton',
#  'Petawawa',
#  'Peterborough',
#  'Port Alberni',
#  'Port Hope',
#  'Portage la Prairie',
#  'Powell River',
#  'Prince Albert',
#  'Prince George',
#  'Prince Rupert',
#  'Quesnel',
#  'Québec',
#  'Red Deer',
#  'Regina',
#  'Rimouski',
#  'Rivière-du-Loup',
#  'Rouyn-Noranda',
#  'Saguenay',
#  'Saint John',
#  'Saint-Georges',
#  'Saint-Hyacinthe',
#  'Sainte-Agathe-des-Monts',
#  'Salaberry-de-Valleyfield',
#  'Salmon Arm',
#  'Sarnia',
#  'Saskatoon',
#  'Sault Ste. Marie',
#  'Sept-Îles',
#  'Shawinigan',
#  'Sherbrooke',
#  'Sorel-Tracy',
#  'Squamish',
#  'St. Catharines - Niagara',
#  "St. John's",
#  'Stratford',
#  'Strathmore',
#  'Summerside',
#  'Swift Current',
#  'Terrace',
#  'Thetford Mines',
#  'Thompson',
#  'Thunder Bay',
#  'Tillsonburg',
#  'Timmins',
#  'Toronto',
#  'Trail',
#  'Trois-Rivières',
#  'Truro',
#  "Val-d'Or",
#  'Vancouver',
#  'Vernon',
#  'Victoria',
#  'Victoriaville',
#  'Wasaga Beach',
#  'Weyburn',
#  'Whitehorse',
#  'Williams Lake',
#  'Windsor',
#  'Winkler',
#  'Winnipeg',
#  'Wood Buffalo',
#  'Woodstock',
#  'Yellowknife',
#  'Yorkton']

# %%
maximumsWithEnoughData = maximums.reset_index()[maximums.reset_index()["CMANAME"].isin(cmasWithEnoughData)].set_index(["CMANAME", "Month", "Day"])

more_testing = pd.DataFrame({"Year": maximumsWithEnoughData.idxmax(axis=1), "Temp": maximumsWithEnoughData.max(axis=1)}).reset_index()
more_testing["Date"] = pd.to_datetime(more_testing["Year"].astype(str) + "-" + more_testing["Month"].astype(str) + "-" + more_testing["Day"].astype(str))
more_testing = more_testing.drop(columns=["Month", "Day", "Year"])
more_testing["days_since_record"] = (pd.datetime.today() - more_testing["Date"]).dt.days - 1

final_2 = []

for city in more_testing["CMANAME"].unique():
    
    d = more_testing[more_testing["CMANAME"] == city]

    d = d[d["days_since_record"] == d["days_since_record"].min()]
    final_2.append(d)
    
pd.concat(final_2).set_index("CMANAME").sort_values("days_since_record")
# Out:
# C:\Users\dexmc\AppData\Local\Temp\ipykernel_67628\3690429432.py:6: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   more_testing["days_since_record"] = (pd.datetime.today() - more_testing["Date"]).dt.days - 1
#                                                     Temp       Date  \
# CMANAME
# Halifax                                             15.1 2022-11-16
# Whitehorse                                           5.7 2022-11-14
# Ottawa - Gatineau (Ontario part / partie de l'O...  14.4 2022-11-12
# Fredericton                                         19.3 2022-11-12
# Sherbrooke                                          20.3 2022-11-12
# ...                                                  ...        ...
# Matane                                              27.0 1993-08-02
# Rimouski                                            22.0 1982-05-25
# Wasaga Beach                                        15.0 1981-04-27
# New Glasgow                                         10.0 1978-11-23
# Lloydminster (Saskatchewan part / partie de la ...  28.3 1976-05-10
#
#                                                     days_since_record
# CMANAME
# Halifax                                                             5
# Whitehorse                                                          7
# Ottawa - Gatineau (Ontario part / partie de l'O...                  9
# Fredericton                                                         9
# Sherbrooke                                                          9
# ...                                                               ...
# Matane                                                          10703
# Rimouski                                                        14790
# Wasaga Beach                                                    15183
# New Glasgow                                                     16069
# Lloydminster (Saskatchewan part / partie de la ...              16996
#
# [105 rows x 3 columns]

# %%
halifax = maximums.reset_index()[maximums.reset_index()["CMANAME"] == "Saint John"].dropna(how='all', axis=1)

halifax.to_csv("data/halifax.csv")

# %%
minimums = joined.pivot_table(columns="CMANAME", values="Min Temp (°C)", index="Date/Time", aggfunc='min')

minimums.tail()
# Out:
# CMANAME     Abbotsford - Mission  Alma  Amos  Baie-Comeau  Barrie  Bathurst  \
# Date/Time
# 2022-11-17                   4.6  -4.8   NaN         -6.6     NaN      -4.1
# 2022-11-18                  -2.7  -7.4   NaN         -9.7     NaN     -10.8
# 2022-11-19                  -4.2 -10.7   NaN        -13.4     NaN     -12.7
# 2022-11-20                  -3.6 -10.1   NaN         -9.6     NaN      -9.1
# 2022-11-21                   0.4 -13.4   NaN        -12.0     NaN      -8.8
#
# CMANAME     Belleville - Quinte West  Brandon  Brantford  Brockville  ...  \
# Date/Time                                                             ...
# 2022-11-17                      -6.8    -17.9       -3.2        -7.5  ...
# 2022-11-18                     -10.2    -18.2       -3.7        -7.5  ...
# 2022-11-19                      -4.2    -16.6       -6.1        -4.6  ...
# 2022-11-20                     -13.2    -15.0       -9.7       -16.8  ...
# 2022-11-21                     -13.5    -11.4       -9.9       -11.7  ...
#
# CMANAME     Weyburn  Whitehorse  Williams Lake  Windsor  Winkler  Winnipeg  \
# Date/Time
# 2022-11-17    -19.1       -11.7           -9.3     -2.8    -13.1     -15.1
# 2022-11-18    -18.7       -14.6          -11.4     -4.9    -15.4     -16.6
# 2022-11-19    -14.6       -13.4          -18.2     -6.6    -14.2     -17.7
# 2022-11-20    -12.3        -5.9          -12.6     -9.2    -13.2     -11.0
# 2022-11-21    -14.1        -1.3           -4.9     -4.9     -5.5     -10.8
#
# CMANAME     Wood Buffalo  Woodstock  Yellowknife  Yorkton
# Date/Time
# 2022-11-17         -18.3        NaN        -13.7    -20.4
# 2022-11-18         -11.1        NaN         -8.4    -16.4
# 2022-11-19         -15.1        NaN        -10.5    -17.9
# 2022-11-20         -10.3        NaN        -11.3    -16.0
# 2022-11-21          -8.7        NaN         -5.3    -12.4
#
# [5 rows x 133 columns]

# %%
minimums = minimums.drop(["2022-11-21"])

minimums.tail()
# Out:
# CMANAME     Abbotsford - Mission  Alma  Amos  Baie-Comeau  Barrie  Bathurst  \
# Date/Time
# 2022-11-16                  -3.8  -4.2   NaN         -7.4     NaN      -3.6
# 2022-11-17                   4.6  -4.8   NaN         -6.6     NaN      -4.1
# 2022-11-18                  -2.7  -7.4   NaN         -9.7     NaN     -10.8
# 2022-11-19                  -4.2 -10.7   NaN        -13.4     NaN     -12.7
# 2022-11-20                  -3.6 -10.1   NaN         -9.6     NaN      -9.1
#
# CMANAME     Belleville - Quinte West  Brandon  Brantford  Brockville  ...  \
# Date/Time                                                             ...
# 2022-11-16                      -2.5    -16.8       -2.3        -3.0  ...
# 2022-11-17                      -6.8    -17.9       -3.2        -7.5  ...
# 2022-11-18                     -10.2    -18.2       -3.7        -7.5  ...
# 2022-11-19                      -4.2    -16.6       -6.1        -4.6  ...
# 2022-11-20                     -13.2    -15.0       -9.7       -16.8  ...
#
# CMANAME     Weyburn  Whitehorse  Williams Lake  Windsor  Winkler  Winnipeg  \
# Date/Time
# 2022-11-16      NaN       -10.0           -7.2      0.7    -13.4     -15.7
# 2022-11-17    -19.1       -11.7           -9.3     -2.8    -13.1     -15.1
# 2022-11-18    -18.7       -14.6          -11.4     -4.9    -15.4     -16.6
# 2022-11-19    -14.6       -13.4          -18.2     -6.6    -14.2     -17.7
# 2022-11-20    -12.3        -5.9          -12.6     -9.2    -13.2     -11.0
#
# CMANAME     Wood Buffalo  Woodstock  Yellowknife  Yorkton
# Date/Time
# 2022-11-16         -16.7        NaN        -19.4    -10.0
# 2022-11-17         -18.3        NaN        -13.7    -20.4
# 2022-11-18         -11.1        NaN         -8.4    -16.4
# 2022-11-19         -15.1        NaN        -10.5    -17.9
# 2022-11-20         -10.3        NaN        -11.3    -16.0
#
# [5 rows x 133 columns]

# %%
maximums.reset_index().to_csv("data/test_data.csv")

# %% [markdown]
# Now let's make a call to ECC's api to test adding new data.

# %%
# Get a list of unique station IDs to iterate through.
listOfStationIds = (stations
                    .loc[stations["DLY Last Year"] == 2022, "Station ID"]
                    .unique()
                    .astype(int)
                    )

listOfStationIds
# Out:
# array([   26,    68,    76, 46728,    87, 54641,    78,  6811,  6812,
#          114, 51337,   145, 52979,   155,   181, 52941, 51318,   189,
#        45627,   209,   225,  8045,  6816,   327, 45807, 52018,   336,
#        48693,   424,   442, 51037,   568,   617, 48370, 48248, 50169,
#          636, 48688, 48108,   650, 50820, 50308, 54238,   706,   707,
#          731,   747, 50368, 49088,   766, 43723,   776,   810,   823,
#         6830,   853,   834,   837,   870, 51357, 51442,  6833,   925,
#        48369, 51117,  1032,  1046, 50269, 46987,  1070,   979,  1137,
#         6839, 31067,  1095, 50818,  1186, 51423, 42203,  1338,  1216,
#         6843, 11006, 11005, 48208, 50837, 55198, 50842, 48168, 51058,
#        55358, 27793, 27214, 30907, 50149, 53718, 51758,  1870,  1886,
#        53998, 47088, 48550,  1920, 46911, 41783, 46850, 43581, 27018,
#        27492, 52458, 49050, 32455, 46447, 50921,  2180, 50430, 27211,
#        52200,  9010, 42728, 46807, 50940, 49268, 51377,  2265, 46867,
#        42726, 48949, 30347, 43580, 50918, 42730, 50919,  2173,  2174,
#        10725,  2513, 27216, 49490, 10978, 31027, 48975, 50757, 51422,
#         2859, 54261, 49728, 27476, 51441, 28011, 49808, 48977, 10666,
#        48976,  3157, 44344, 48609, 51878, 54498, 50091, 47707, 50821,
#        49909, 45987,  3519,  3619, 29593,  3641,  6889, 43185, 51097,
#        28051, 27174, 47307, 51137, 54378, 49389, 50132, 30682, 26912,
#        50092, 54838, 49508, 50840, 47547, 50460, 52318, 54604,  6901,
#        47567,  4236,  4255,  4287, 27534, 47267, 52985,  4333, 30578,
#        49568, 49068, 47527,  6900, 43540, 50048, 10955,  6904,  4525,
#        54259, 53139, 27604, 48373, 44323,  4607, 52118, 27528, 44123,
#        30266,  4647,  4671, 32473,  4680, 53000,  4689,  4699, 31367,
#        44283,  4715, 54738,  9005, 27533, 53378, 41983,  4760,  4761,
#        45407, 55299, 48569, 50093, 10999,  4816, 27647,  4835, 55238,
#         7868,  4905,  4923, 49908, 27529, 54958, 45667, 48649,  4996,
#        51938, 31688, 48549, 54239, 51459, 30723,  5126, 50637, 29846,
#        48952, 43763, 31010, 44205,  5217,  8989,  5237,  5239,  5248,
#        51457, 27646, 52138, 51698,  8321, 29452, 27377, 26892,  5310,
#         5327,  5348,  5369, 42013,  5389,  5393,  5397,  5401, 10761,
#        51157,  5485, 48374,  5492, 47587,  5532,  5542, 45309, 10801,
#        10873, 10843, 30165,  5574,  5585, 53001, 27717,  5594,  5604,
#        49608,  5631, 30173, 48968, 10963, 52199, 42683, 26889,  5836,
#         8539, 55359,  5889,  5911, 30722, 10797, 27315,  5977,  5988,
#        10849, 50090,  6081, 30172, 49390,  6005, 54283, 10808, 43323,
#        48568, 30309,  6194, 50309, 54282, 49868, 50310, 55378, 43406,
#        43123, 42243, 49748, 53938, 50620, 43124, 43403, 27141, 27742,
#        54578, 30668, 44363,  6435, 52202, 54639, 47187, 10945, 52518,
#        44503, 54281, 50621,  6537, 10800, 30308,  6933,  6610, 50088,
#        30346, 50089, 48871])

# %%
li = []

# Get a list of unique station IDs to iterate through.
listOfStationIds = (stations
                    .loc[stations["Last Year"] == 2022, "Station ID"]
                    .unique()
                    .astype(int)
                    )

for stationId in listOfStationIds[0:10]:

    df = pd.read_csv(f'https://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID={str(stationId)}&Year=2022&Month=11&Day=21&timeframe=2')
    df = df.loc[df["Date/Time"] == "2022-11-21",:]
    df = df[[ "Climate ID", "Year", "Month", "Day", "Date/Time", "Max Temp (°C)", "Min Temp (°C)"]]
    li.append(df)
    
new_data = pd.concat(li).set_index("Climate ID")

# %%
new_data.index = new_data.index.astype(str)

# %%
new_data
# Out:
#             Year  Month  Day   Date/Time  Max Temp (°C)  Min Temp (°C)
# Climate ID
# 1011500     2022     11   21  2022-11-21            NaN            NaN
# 1015105     2022     11   21  2022-11-21            NaN            NaN
# 1015628     2022     11   21  2022-11-21            NaN            NaN
# 1015630     2022     11   21  2022-11-21            9.0            3.1
# 1016940     2022     11   21  2022-11-21            NaN            4.5
# 1016943     2022     11   21  2022-11-21            8.9            4.5
# 1016RM0     2022     11   21  2022-11-21            NaN            NaN
# 1017254     2022     11   21  2022-11-21            8.5            5.6
# 1018598     2022     11   21  2022-11-21            8.7            4.6
# 1018611     2022     11   21  2022-11-21            9.5            4.4

# %%
new_joined = new_data.join(stations)

new_joined.tail()
# Out:
#             Year  Month  Day   Date/Time  Max Temp (°C)  Min Temp (°C)  \
# Climate ID
# 1016943     2022     11   21  2022-11-21            8.9            4.5
# 1016RM0     2022     11   21  2022-11-21            NaN            NaN
# 1017254     2022     11   21  2022-11-21            8.5            5.6
# 1018598     2022     11   21  2022-11-21            8.7            4.6
# 1018611     2022     11   21  2022-11-21            9.5            4.4
#
#             Station ID                    Name     Latitude     Longitude  \
# Climate ID
# 1016943          54641         SAANICHTON CFIA  483718000.0 -1.232508e+09
# 1016RM0             78    SAANICHTON MT NEWTON  483551000.0 -1.232538e+09
# 1017254           6811        SHERINGHAM POINT  482236100.0 -1.235516e+09
# 1018598           6812  VICTORIA UNIVERSITY CS  482725200.0 -1.231817e+09
# 1018611            114    VICTORIA GONZALES CS  482447896.0 -1.231929e+09
#
#             First Year  Last Year  DLY First Year  DLY Last Year  CMAUID  \
# Climate ID
# 1016943           2020       2022          2020.0         2022.0     935
# 1016RM0           1980       2022          1980.0         2022.0     935
# 1017254           1992       2022          1992.0         2022.0     935
# 1018598           1992       2022          1992.0         2022.0     935
# 1018611           1972       2022          1973.0         2022.0     935
#
#              CMANAME PRUID
# Climate ID
# 1016943     Victoria    BC
# 1016RM0     Victoria    BC
# 1017254     Victoria    BC
# 1018598     Victoria    BC
# 1018611     Victoria    BC

# %%
# new_joined["Day"] = new_joined["Date/Time"].day
# new_joined["Month"] = new_joined["Date/Time"].month
# new_joined["Year"] = new_joined["Date/Time"].year

maximums_new = new_joined.pivot_table(columns="Year", values="Max Temp (°C)", index=["CMANAME", "Month", "Day"], aggfunc='max')

maximums_new.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dexmc\Documents\Code\weather-records-app\weather_scripts\testing.ipynb Cell 24 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # new_joined["Day"] = new_joined["Date/Time"].day
#       <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> # new_joined["Month"] = new_joined["Date/Time"].month
#       <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> # new_joined["Year"] = new_joined["Date/Time"].year
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a> maximums_new = new_joined.pivot_table(columns="Year", values="Max Temp (°C)", index=["CMANAME", "Month", "Day"], aggfunc='max')
#       <a href='vscode-notebook-cell:/c%3A/Users/dexmc/Documents/Code/weather-records-app/weather_scripts/testing.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> maximums_new.head()
#
# NameError: name 'new_joined' is not defined

# %%
final = pd.concat([maximums, maximums_new]).drop_duplicates()

final
# Out:
# Year                            1889  1890  1891  1892  1893  1894  1895  \
# CMANAME              Month Day
# Abbotsford - Mission 1     1     NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            2     NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            3     NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            4     NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            5     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                              ...   ...   ...   ...   ...   ...   ...
# Yorkton              12    27    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            28    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            29    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            30    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                            31    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# Year                            1896  1897  1898  ...  2013  2014  2015  2016  \
# CMANAME              Month Day                    ...
# Abbotsford - Mission 1     1     NaN   NaN   NaN  ...   2.0   6.0   2.0   1.0
#                            2     NaN   NaN   NaN  ...   4.5   9.0   2.0   1.0
#                            3     NaN   NaN   NaN  ...   4.5   4.5   2.5   1.5
#                            4     NaN   NaN   NaN  ...   3.0   4.0   0.5   2.0
#                            5     NaN   NaN   NaN  ...   4.5   5.0   6.0   2.0
# ...                              ...   ...   ...  ...   ...   ...   ...   ...
# Yorkton              12    27    NaN   NaN   NaN  ...   1.0 -13.0 -16.0   NaN
#                            28    NaN   NaN   NaN  ... -22.0 -22.0 -11.0   NaN
#                            29    NaN   NaN   NaN  ... -26.0 -23.0 -14.0   NaN
#                            30    NaN   NaN   NaN  ... -26.0 -12.0  -7.0   NaN
#                            31    NaN   NaN   NaN  ... -27.0  -5.0  -5.0   NaN
#
# Year                            2017  2018  2019  2020  2021  2022
# CMANAME              Month Day
# Abbotsford - Mission 1     1     1.0  -1.0   5.0  11.5   9.0   0.0
#                            2    -1.0   2.5   6.0   7.5   9.0   4.0
#                            3    -1.5   4.0   9.0  14.0   7.5   4.0
#                            4     2.0   5.0  10.5   6.5   9.0   3.0
#                            5    -1.0   8.0   7.5   6.0   9.0   0.0
# ...                              ...   ...   ...   ...   ...   ...
# Yorkton              12    27    NaN   NaN   NaN   NaN   NaN   NaN
#                            28    NaN   NaN   NaN   NaN   NaN   NaN
#                            29    NaN   NaN   NaN   NaN   NaN   NaN
#                            30    NaN   NaN   NaN   NaN   NaN   NaN
#                            31    NaN   NaN   NaN   NaN   NaN   NaN
#
# [39776 rows x 131 columns]

# %%
def getMaxForDate(date)
    maxData = []

    for col_name, data in final.iloc[:, 0:1].iteritems():
        data = pd.DataFrame({"temp": data})
        data["Day"] = pd.to_datetime(data.index).day.astype(int)
        data["Month"] = pd.to_datetime(data.index).month.astype(int)
        data["Year"] = pd.to_datetime(data.index).year.astype(int)
        
        pivot = data.pivot(index=["Month", "Day"], columns="Year").dropna(axis=1, how='all')
        
        display(pivot)
# Out:
#           temp                                                  ...            \
# Year      1909 1910 1911 1912 1913  1914 1915 1916  1917  1918  ... 2013 2014
# Month Day                                                       ...
# 1     1    NaN  1.1  NaN  4.4  6.1   6.1  7.2 -0.6   1.7  10.6  ...  2.0  6.0
#       2    NaN  0.0  2.2 -6.7  3.9   8.9  7.2 -1.1   1.7  11.1  ...  4.5  9.0
#       3    NaN  0.6  0.0 -9.4  1.7   9.4  5.6  0.0   1.7  10.0  ...  4.5  4.5
#       4    NaN  2.8  4.4 -3.3 -5.6   7.2  3.9 -1.1   1.7   7.8  ...  3.0  4.0
#       5    NaN -0.6  4.4 -3.9 -3.3  11.1  3.9 -0.6   6.1   8.3  ...  4.5  5.0
# ...        ...  ...  ...  ...  ...   ...  ...  ...   ...   ...  ...  ...  ...
# 12    27   3.3  7.8  9.4  2.8  7.2   5.6  3.3 -2.8   3.3   6.1  ...  6.5  4.5
#       28   3.9  6.1  8.3  7.2  8.9   5.0  2.8 -2.2   5.0   7.2  ...  7.0  5.0
#       29   1.1  5.6  7.2  4.4  7.2   3.3  3.9  1.7   8.3   6.7  ...  5.0  2.5
#       30   3.3  5.0 -1.1  5.6  7.2   5.6  2.2 -1.7  12.8   5.0  ...  6.5  0.0
#       31   5.6  0.6  NaN  5.6  7.2   6.1 -1.7  1.1  12.8   3.3  ...  6.0  1.0
#
#
# Year      2015 2016 2017  2018  2019  2020  2021 2022
# Month Day
# 1     1    2.0  1.0  1.0  -1.0   5.0  11.5   9.0  0.0
#       2    2.0  1.0 -1.0   2.5   6.0   7.5   9.0  4.0
#       3    2.5  1.5 -1.5   4.0   9.0  14.0   7.5  4.0
#       4    0.5  2.0  2.0   5.0  10.5   6.5   9.0  3.0
#       5    6.0  2.0 -1.0   8.0   7.5   6.0   9.0  0.0
# ...        ...  ...  ...   ...   ...   ...   ...  ...
# 12    27   0.5  5.0 -1.0   4.5   3.5   4.5 -12.5  NaN
#       28   2.5  4.0 -0.5   9.5   4.5   5.5  -8.5  NaN
#       29   4.5  4.0  1.0  10.0   7.5   5.0  -1.0  NaN
#       30   2.0  4.0  0.0   7.0   7.0   5.0  -2.0  NaN
#       31   1.0  1.0 -1.0   4.5  10.0   5.0  -6.0  NaN
#
# [366 rows x 114 columns]

# %%
pd.DataFrame({"Date of record": final.idxmax()})
# Out:
#                             Test
# CMANAME
# Abbotsford - Mission  2021-06-28
# Alma                  1975-08-01
# Amos                  1921-07-03
# Baie-Comeau           2020-06-18
# Barrie                1973-08-09
# ...                          ...
# Winnipeg              1983-09-02
# Wood Buffalo          2021-06-30
# Woodstock             1989-07-11
# Yellowknife           2018-08-11
# Yorkton               1980-05-22
#
# [133 rows x 1 columns]

# %%
max = pd.read_csv("data/raw_data.csv")

max
# Out:
#                     CMANAME  Month  Day  1889  1890  1891  1892  1893  1894  \
# 0      Abbotsford - Mission      1    1   NaN   NaN   NaN   NaN   NaN   NaN
# 1      Abbotsford - Mission      1    2   NaN   NaN   NaN   NaN   NaN   NaN
# 2      Abbotsford - Mission      1    3   NaN   NaN   NaN   NaN   NaN   NaN
# 3      Abbotsford - Mission      1    4   NaN   NaN   NaN   NaN   NaN   NaN
# 4      Abbotsford - Mission      1    5   NaN   NaN   NaN   NaN   NaN   NaN
# ...                     ...    ...  ...   ...   ...   ...   ...   ...   ...
# 42583               Yorkton     12   27   NaN   NaN   NaN   NaN   NaN   NaN
# 42584               Yorkton     12   28   NaN   NaN   NaN   NaN   NaN   NaN
# 42585               Yorkton     12   29   NaN   NaN   NaN   NaN   NaN   NaN
# 42586               Yorkton     12   30   NaN   NaN   NaN   NaN   NaN   NaN
# 42587               Yorkton     12   31   NaN   NaN   NaN   NaN   NaN   NaN
#
#        1895  ...  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0       NaN  ...   2.0   6.0   2.0   1.0   1.0  -1.0   5.0  11.5   9.0   0.0
# 1       NaN  ...   4.5   9.0   2.0   1.0  -1.0   2.5   6.0   7.5   9.0   4.0
# 2       NaN  ...   4.5   4.5   2.5   1.5  -1.5   4.0   9.0  14.0   7.5   4.0
# 3       NaN  ...   3.0   4.0   0.5   2.0   2.0   5.0  10.5   6.5   9.0   3.0
# 4       NaN  ...   4.5   5.0   6.0   2.0  -1.0   8.0   7.5   6.0   9.0   0.0
# ...     ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 42583   NaN  ...   1.0 -13.0 -16.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 42584   NaN  ... -22.0 -22.0 -11.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 42585   NaN  ... -26.0 -23.0 -14.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 42586   NaN  ... -26.0 -12.0  -7.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 42587   NaN  ... -27.0  -5.0  -5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [42588 rows x 134 columns]

# %%
raw = pd.read_csv("./data/raw_data2.csv")

raw["Date"] = pd.to_datetime(raw["Year"].astype(str) + "-" + raw["Month"].astype(str) + "-" + raw["Day"].astype(str))
# Out:
#          Unnamed: 0    index  CMANAME  Month  Day  Year  value       Date
# 0                 0        0  Toronto      3    1  1840    8.3 1840-03-01
# 1                 1        1  Toronto      3    2  1840    7.8 1840-03-02
# 2                 2        2  Toronto      3    3  1840   11.1 1840-03-03
# 3                 3        3  Toronto      3    4  1840   15.0 1840-03-04
# 4                 4        4  Toronto      3    5  1840    6.7 1840-03-05
# ...             ...      ...      ...    ...  ...   ...    ...        ...
# 5372250     5372250  5372250  Yorkton     11   17  2022   -9.7 2022-11-17
# 5372251     5372251  5372251  Yorkton     11   18  2022   -6.0 2022-11-18
# 5372252     5372252  5372252  Yorkton     11   19  2022   -6.4 2022-11-19
# 5372253     5372253  5372253  Yorkton     11   20  2022   -2.9 2022-11-20
# 5372254     5372254  5372254  Yorkton     11   21  2022   -1.6 2022-11-21
#
# [5372255 rows x 8 columns]

# %%
max_date = raw["Date"].max().date()

max_date
# Out:
# datetime.date(2022, 11, 21)
